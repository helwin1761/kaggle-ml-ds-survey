# %%
import pandas as pd

# %%
qs_2017=pd.read_csv("/Users/helwinlin/Downloads/kaggle_ml_ds_survey/kaggle-survey-2017/schema.csv")

# %%
qs_2018=pd.read_csv("/Users/helwinlin/Downloads/kaggle_ml_ds_survey/kaggle-survey-2018/SurveySchema.csv")

# %%
qs_2019=pd.read_csv("/Users/helwinlin/Downloads/kaggle_ml_ds_survey/kaggle-survey-2019/questions_only.csv")

# %%
qs_2017
# Out:
#                              Column  \
# 0                      GenderSelect
# 1                    GenderFreeForm
# 2                           Country
# 3                               Age
# 4                  EmploymentStatus
# ..                              ...
# 285                 JobFactorRemote
# 286               JobFactorIndustry
# 287       JobFactorLeaderReputation
# 288              JobFactorDiversity
# 289  JobFactorPublishingOpportunity
#
#                                               Question     Asked
# 0       Select your gender identity. - Selected Choice       All
# 1    Select your gender identity. - A different ide...       All
# 2            Select the country you currently live in.       All
# 3                                     What's your age?       All
# 4               What's your current employment status?       All
# ..                                                 ...       ...
# 285  How are you assessing potential job opportunit...  Learners
# ...

# %%
qs_2018.head(1)
# Out:
#   2018 Kaggle Machine Learning and Data Science Survey  \
# 0                                          Question:
#
#                                        Q1  \
# 0  What is your gender? - Selected Choice
#
#                                                  Q10  \
# 0  Does your current employer incorporate machine...
#
#                                                  Q11  \
# 0  Select any activities that make up an importan...
#
#                                                  Q12  \
# 0  What is the primary tool that you use at work ...
#
#                                                  Q13  \
# 0  Which of the following integrated development ...
#
#                                                  Q14  \
# 0  Which of the following hosted notebooks have y...
#
#                                                  Q15  \
# 0  Which of the following cloud computing service...
#
#                                                  Q16  \
# ...

# %%
qs_2018.loc[0]
# Out:
# 2018 Kaggle Machine Learning and Data Science Survey                                            Question:
# Q1                                                                 What is your gender? - Selected Choice
# Q10                                                     Does your current employer incorporate machine...
# Q11                                                     Select any activities that make up an importan...
# Q12                                                     What is the primary tool that you use at work ...
# Q13                                                     Which of the following integrated development ...
# Q14                                                     Which of the following hosted notebooks have y...
# Q15                                                     Which of the following cloud computing service...
# Q16                                                     What programming languages do you use on a reg...
# ...

# %%
qs_2019.head()
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
#
#                                           Q3  \
# 0  In which country do you currently reside?
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
#
#                                                   Q5  \
# 0  Select the title most similar to your current ...
#
#                                                   Q6  \
# 0  What is the size of the company where you are ...
#
#                                                   Q7  \
# 0  Approximately how many individuals are respons...
#
#                                                   Q8  \
# 0  Does your current employer incorporate machine...
#
#                                                   Q9  ...  \
# ...

# %%
for col,qs in zip(qs_2017["Column"],qs_2017["Question"]):
    print("{}:{}".format(col,qs))
# Out:
# GenderSelect:Select your gender identity. - Selected Choice
# GenderFreeForm:Select your gender identity. - A different identity - Text
# Country:Select the country you currently live in.
# Age:What's your age?
# EmploymentStatus:What's your current employment status?
# StudentStatus:Are you currently enrolled as a student at a degree granting school?
# LearningDataScience:Are you currently focused on learning data science skills either formally or informally?
# KaggleMotivationFreeForm:What's your motivation for being a Kaggle user?
# CodeWriter:Do you write code to analyze data in your current job, freelance contracts, or most recent job if retired?
# CareerSwitcher:Are you actively looking to switch careers to data science?
# CurrentJobTitleSelect:Select the option that's most similar to your current job/professional title (or most recent title if retired). - Selected Choice
# ...

# %%
for i in range(1,51):
    col_name="Q{}".format(i)
    print("Q{}:{}".format(i,qs_2018.loc[0,col_name])) #取出0列的col_name資訊
# Out:
# Q1:What is your gender? - Selected Choice
# Q2:What is your age (# years)?
# Q3:In which country do you currently reside?
# Q4:What is the highest level of formal education that you have attained or plan to attain within the next 2 years?
# Q5:Which best describes your undergraduate major? - Selected Choice
# Q6:Select the title most similar to your current role (or most recent title if retired): - Selected Choice
# Q7:In what industry is your current employer/contract (or your most recent employer if retired)? - Selected Choice
# Q8:How many years of experience do you have in your current role?
# Q9:What is your current yearly compensation (approximate $USD)?
# Q10:Does your current employer incorporate machine learning methods into their business?
# Q11:Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice
# ...

# %%
for i in range(1,35):
    col_name="Q{}".format(i)
    print("Q{}:{}".format(i,qs_2019.loc[0,col_name]))
# Out:
# Q1:What is your age (# years)?
# Q2:What is your gender? - Selected Choice
# Q3:In which country do you currently reside?
# Q4:What is the highest level of formal education that you have attained or plan to attain within the next 2 years?
# Q5:Select the title most similar to your current role (or most recent title if retired): - Selected Choice
# Q6:What is the size of the company where you are employed?
# Q7:Approximately how many individuals are responsible for data science workloads at your place of business?
# Q8:Does your current employer incorporate machine learning methods into their business?
# Q9:Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice
# Q10:What is your current yearly compensation (approximate $USD)?
# Q11:Approximately how much money have you spent on machine learning and/or cloud computing products at your work in the past 5 years?
# ...

# %% [markdown]
# # 檢視kaggle survey問卷內容

# %%
survey_2017=pd.read_csv("/Users/helwinlin/Downloads/kaggle_ml_ds_survey/kaggle-survey-2017/multipleChoiceResponses.csv",encoding="iso-8859-1",low_memory=False)
survey_2017
# Out:
#                                             GenderSelect        Country   Age  \
# 0      Non-binary, genderqueer, or gender non-conforming            NaN   NaN
# 1                                                 Female  United States  30.0
# 2                                                   Male         Canada  28.0
# 3                                                   Male  United States  56.0
# 4                                                   Male         Taiwan  38.0
# ...                                                  ...            ...   ...
# 16711                                             Female          Other  24.0
# 16712                                               Male      Indonesia  25.0
# 16713                                             Female         Taiwan  25.0
# 16714                                             Female      Singapore  16.0
# 16715                                               Male          Japan  27.0
#
# ...

# %%
survey_2018=pd.read_csv("/Users/helwinlin/Downloads/kaggle_ml_ds_survey/kaggle-survey-2018/multipleChoiceResponses.csv",low_memory=False,skiprows=[1])
survey_2018
# Out:
#        Time from Start to Finish (seconds)      Q1  Q1_OTHER_TEXT     Q2  \
# 0                                      710  Female             -1  45-49
# 1                                      434    Male             -1  30-34
# 2                                      718  Female             -1  30-34
# 3                                      621    Male             -1  35-39
# 4                                      731    Male             -1  22-24
# ...                                    ...     ...            ...    ...
# 23854                                  575    Male             -1  45-49
# 23855                                  131  Female             -1  25-29
# 23856                                  370    Male             -1  22-24
# 23857                                   36    Male             -1  25-29
# 23858                                  502    Male             -1  25-29
#
#                                                       Q3                 Q4  \
# ...

# %%
survey_2019=pd.read_csv("/Users/helwinlin/Downloads/kaggle_ml_ds_survey/kaggle-survey-2019/multiple_choice_responses.csv",low_memory=False)
survey_2019
# Out:
#       Time from Start to Finish (seconds)                           Q1  \
# 0                   Duration (in seconds)  What is your age (# years)?
# 1                                     510                        22-24
# 2                                     423                        40-44
# 3                                      83                        55-59
# 4                                     391                        40-44
# ...                                   ...                          ...
# 19713                                  84                        50-54
# 19714                                 473                        18-21
# 19715                                9195                        35-39
# 19716                                 176                        25-29
# 19717                                 567                        50-54
#
#                                            Q2  \
# 0      What is your gender? - Selected Choice
# ...

# %%
print(survey_2017.shape)
print(survey_2018.shape)
print(survey_2019.shape)
# Out:
# (16716, 228)
# (23859, 395)
# (19718, 246)

# %%
print(survey_2017.shape[0])
print(survey_2018.shape[0])
print(survey_2019.shape[0])
# Out:
# 16716
# 23859
# 19718

# %%
def print_repondents_info(year,df,col_name):
    ttl_respondents=df.shape[0]
    job_title_value_counts=df[col_name].value_counts()
    job_title_percentage=(job_title_value_counts/ttl_respondents)*100
    print("{}年的總答題人數為{}".format(year,ttl_respondents))
    print("{}年的Data Analyst人數為{:,};比例為{:.2f}%".format(year,job_title_value_counts["Data Analyst"],job_title_percentage["Data Analyst"]))

# %%
print_repondents_info(2017,survey_2017,"CurrentJobTitleSelect")
# Out:
# 2017年的總答題人數為16716
# 2017年的Data Analyst人數為1,213;比例為7.26%

# %%
print_repondents_info(2018,survey_2018,"Q6")
# Out:
# 2018年的總答題人數為23859
# 2018年的Data Analyst人數為1,922;比例為8.06%

# %%
print_repondents_info(2019,survey_2019,"Q5")
# Out:
# 2019年的總答題人數為19718
# 2019年的Data Analyst人數為1,598;比例為8.10%

# %%
survey_2017["CurrentJobTitleSelect"].value_counts()
# Out:
# Data Scientist                          2433
# Software Developer/Software Engineer    1759
# Other                                   1233
# Data Analyst                            1213
# Scientist/Researcher                     978
# Business Analyst                         796
# Researcher                               619
# Machine Learning Engineer                617
# Engineer                                 552
# Programmer                               462
# Computer Scientist                       335
# Statistician                             289
# DBA/Database Engineer                    187
# Predictive Modeler                       181
# Data Miner                               118
# Operations Research Practitioner          58
# Name: CurrentJobTitleSelect, dtype: int64

# %%
survey_2018["Q6"].value_counts()
# Out:
# Student                    5253
# Data Scientist             4137
# Software Engineer          3130
# Data Analyst               1922
# Other                      1322
# Research Scientist         1189
# Not employed                842
# Consultant                  785
# Business Analyst            772
# Data Engineer               737
# Research Assistant          600
# Manager                     590
# Product/Project Manager     428
# Chief Officer               360
# Statistician                237
# DBA/Database Engineer       145
# Developer Advocate          117
# Marketing Analyst           115
# Salesperson                 102
# Principal Investigator       97
# Data Journalist              20
# Name: Q6, dtype: int64

# %%
survey_2019["Q5"].value_counts()
# Out:
# Data Scientist                                                                                             4085
# Student                                                                                                    4014
# Software Engineer                                                                                          2705
# Other                                                                                                      1690
# Data Analyst                                                                                               1598
# Research Scientist                                                                                         1470
# Not employed                                                                                                942
# Business Analyst                                                                                            778
# ...

# %%
(survey_2017["CurrentJobTitleSelect"].value_counts()/survey_2017.shape[0])*100
# Out:
# Data Scientist                          14.554917
# Software Developer/Software Engineer    10.522852
# Other                                    7.376167
# Data Analyst                             7.256521
# Scientist/Researcher                     5.850682
# Business Analyst                         4.761905
# Researcher                               3.703039
# Machine Learning Engineer                3.691074
# Engineer                                 3.302225
# Programmer                               2.763819
# Computer Scientist                       2.004068
# Statistician                             1.728883
# DBA/Database Engineer                    1.118689
# Predictive Modeler                       1.082795
# Data Miner                               0.705911
# Operations Research Practitioner         0.346973
# Name: CurrentJobTitleSelect, dtype: float64

# %%
da_2017=survey_2017[survey_2017['CurrentJobTitleSelect'] == 'Data Analyst']
da_2017
# Out:
#       GenderSelect        Country   Age    EmploymentStatus StudentStatus  \
# 25            Male         Russia  22.0  Employed full-time           NaN
# 62            Male      Singapore  24.0  Employed full-time           NaN
# 112         Female  United States  27.0  Employed part-time           NaN
# 119           Male          India  25.0  Employed full-time           NaN
# 126         Female  United States  29.0  Employed full-time           NaN
# ...            ...            ...   ...                 ...           ...
# 16692         Male         Norway  34.0  Employed full-time           NaN
# 16693         Male          India  28.0  Employed full-time           NaN
# 16698         Male      Australia   NaN  Employed full-time           NaN
# 16702         Male      Australia  25.0  Employed full-time           NaN
# 16703         Male          Other  25.0  Employed full-time           NaN
#
#       LearningDataScience CodeWriter CareerSwitcher CurrentJobTitleSelect  \
# ...

# %%
da_2018 = survey_2018[survey_2018['Q6'] == 'Data Analyst']
da_2018
# Out:
#        Time from Start to Finish (seconds)      Q1  Q1_OTHER_TEXT     Q2  \
# 4                                      731    Male             -1  22-24
# 14                                     846  Female             -1  25-29
# 27                                    3266  Female             -1  30-34
# 33                                    1163  Female             -1  25-29
# 46                                    2265    Male             -1  35-39
# ...                                    ...     ...            ...    ...
# 23785                                  282    Male             -1  25-29
# 23786                                  877    Male             -1  25-29
# 23798                                  439    Male             -1  30-34
# 23838                                  180    Male             -1  22-24
# 23849                                  820  Female             -1  18-21
#
#                                  Q3                 Q4  \
# ...

# %%
da_2019 = survey_2019[survey_2019['Q5'] == 'Data Analyst']
da_2019
# Out:
#       Time from Start to Finish (seconds)     Q1      Q2 Q2_OTHER_TEXT  \
# 16                                    485  50-54  Female            -1
# 21                                   1529  22-24  Female            -1
# 33                                    884  25-29  Female            -1
# 37                                    384  35-39    Male            -1
# 38                                    973  25-29    Male            -1
# ...                                   ...    ...     ...           ...
# 19652                               33108  22-24    Male            -1
# 19657                                5380  25-29    Male            -1
# 19672                                 104  25-29  Female            -1
# 19685                                 331  30-34    Male            -1
# 19700                                1480    70+    Male            -1
#
#                              Q3  \
# 16     United States of America
# 21                      Ireland
# ...

# %%
da_2017['JobFunctionSelect'].value_counts()
# Out:
# Analyze and understand data to influence product or business decisions                                                631
# Build and/or run the data infrastructure that your business uses for storing, analyzing, and operationalizing data     98
# Build and/or run a machine learning service that operationally improves your product or workflows                      73
# Build prototypes to explore applying machine learning to new areas                                                     47
# Other                                                                                                                  27
# Research that advances the state of the art of machine learning                                                        11
# Name: JobFunctionSelect, dtype: int64

# %%
da_2017['JobFunctionSelect'].value_counts().sum()
# Out:
# 887

# %%
(da_2017['JobFunctionSelect'].value_counts()/da_2017['JobFunctionSelect'].value_counts().sum())*100
# Out:
# Analyze and understand data to influence product or business decisions                                                71.138670
# Build and/or run the data infrastructure that your business uses for storing, analyzing, and operationalizing data    11.048478
# Build and/or run a machine learning service that operationally improves your product or workflows                      8.229989
# Build prototypes to explore applying machine learning to new areas                                                     5.298760
# Other                                                                                                                  3.043968
# Research that advances the state of the art of machine learning                                                        1.240135
# Name: JobFunctionSelect, dtype: float64

# %%
def get_value_ratios(df,col_name):
    return (df[col_name].value_counts()/df[col_name].value_counts().sum())*100

# %%
get_value_ratios(da_2017,'JobFunctionSelect')
# Out:
# Analyze and understand data to influence product or business decisions                                                71.138670
# Build and/or run the data infrastructure that your business uses for storing, analyzing, and operationalizing data    11.048478
# Build and/or run a machine learning service that operationally improves your product or workflows                      8.229989
# Build prototypes to explore applying machine learning to new areas                                                     5.298760
# Other                                                                                                                  3.043968
# Research that advances the state of the art of machine learning                                                        1.240135
# Name: JobFunctionSelect, dtype: float64

# %%
da_2018["Q11_Part_1"].value_counts().index
# Out:
# Index(['Analyze and understand data to influence product or business decisions'], dtype='object')

# %%
da_2018["Q11_Part_1"].value_counts()
# Out:
# Analyze and understand data to influence product or business decisions    1287
# Name: Q11_Part_1, dtype: int64

# %%
da_2018["Q11_Part_1"].value_counts().values
# Out:
# array([1287])

# %%
da_2018["Q11_Part_1"]
# Out:
# 4                                                      NaN
# 14       Analyze and understand data to influence produ...
# 27       Analyze and understand data to influence produ...
# 33       Analyze and understand data to influence produ...
# 46                                                     NaN
#                                ...
# 23785                                                  NaN
# 23786    Analyze and understand data to influence produ...
# 23798                                                  NaN
# 23838                                                  NaN
# 23849    Analyze and understand data to influence produ...
# Name: Q11_Part_1, Length: 1922, dtype: object

# %%
channel_names = [] # 複選題的選項
channel_checks = [] # 複選題的勾選數
for col_name in da_2018.columns:
        # 將符合複選題的題目特徵（或題號特徵）的變數欄位納入
        # 排除題目特徵中有 OTHER_TEXT 這種開放式回答的變數欄位
    if ("Q11" in col_name) and ('OTHER_TEXT' not in col_name):
        channel_name = da_2018[col_name].value_counts().index # 取出複選題選項
        channel_check = da_2018[col_name].value_counts().values # 取出複選題的勾選數
            # 排除空字串的複選題選項
        if channel_name.size != 0:
            channel_names.append(channel_name[0]) # 存入複選題選項
            channel_checks.append(channel_check[0]) # 存入複選題勾選數
print(channel_names)
print(channel_checks)
# Out:
# ['Analyze and understand data to influence product or business decisions', 'Build and/or run a machine learning service that operationally improves my product or workflows', 'Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data', 'Build prototypes to explore applying machine learning to new areas', 'Do research that advances the state of the art of machine learning', 'None of these activities are an important part of my role at work', 'Other']
# [1287, 360, 610, 426, 253, 97, 69]

# %%
channel_counts=pd.Series(channel_checks,index=channel_names)    
channel_counts
# Out:
# Analyze and understand data to influence product or business decisions                                              1287
# Build and/or run a machine learning service that operationally improves my product or workflows                      360
# Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data     610
# Build prototypes to explore applying machine learning to new areas                                                   426
# Do research that advances the state of the art of machine learning                                                   253
# None of these activities are an important part of my role at work                                                     97
# Other                                                                                                                 69
# dtype: int64

# %%
channel_names = [] # 複選題的選項
channel_checks = [] # 複選題的勾選數
for col_name in da_2018.columns:
        # 將符合複選題的題目特徵（或題號特徵）的變數欄位納入
        # 排除題目特徵中有 OTHER_TEXT 這種開放式回答的變數欄位
    if ("Q11" in col_name) and ('OTHER_TEXT' not in col_name):
        channel_name = da_2018[col_name].value_counts().index # 取出複選題選項
        channel_check = da_2018[col_name].value_counts().values # 取出複選題的勾選數
            # 排除空字串的複選題選項
        if channel_name.size != 0:
            channel_names.append(channel_name[0]) # 存入複選題選項
            channel_checks.append(channel_check[0]) # 存入複選題勾選數
channel_counts=pd.Series(channel_checks,index=channel_names)
channel_ratios=(channel_counts/channel_counts.sum()).sort_values(ascending=False)
print(channel_ratios)
# Out:
# Analyze and understand data to influence product or business decisions                                              0.414894
# Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data    0.196647
# Build prototypes to explore applying machine learning to new areas                                                  0.137331
# Build and/or run a machine learning service that operationally improves my product or workflows                     0.116054
# Do research that advances the state of the art of machine learning                                                  0.081560
# None of these activities are an important part of my role at work                                                   0.031270
# Other                                                                                                               0.022244
# dtype: float64

# %%
channel_ratios=(channel_counts/channel_counts.sum()).sort_values(ascending=False)
channel_ratios
# Out:
# Analyze and understand data to influence product or business decisions                                              0.414894
# Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data    0.196647
# Build prototypes to explore applying machine learning to new areas                                                  0.137331
# Build and/or run a machine learning service that operationally improves my product or workflows                     0.116054
# Do research that advances the state of the art of machine learning                                                  0.081560
# None of these activities are an important part of my role at work                                                   0.031270
# Other                                                                                                               0.022244
# dtype: float64

# %%
def get_checkbox_ratios(df, col_pattern):
    channel_names = [] # 複選題的選項
    channel_checks = [] # 複選題的勾選數
    for col_name in df.columns:
        # 將符合複選題的題目特徵（或題號特徵）的變數欄位納入
        # 排除題目特徵中有 OTHER_TEXT 這種開放式回答的變數欄位
        if (col_pattern in col_name) and ('OTHER_TEXT' not in col_name):
            channel_name = df[col_name].value_counts().index # 取出複選題選項
            channel_check = df[col_name].value_counts().values # 取出複選題的勾選數
            # 排除空字串的複選題選項
            if channel_name.size != 0:
                channel_names.append(channel_name[0]) # 存入複選題選項
                channel_checks.append(channel_check[0]) # 存入複選題勾選數
    channel_counts=pd.Series(channel_checks,index=channel_names)
    channel_ratios=(channel_counts/channel_counts.sum()).sort_values(ascending=False)
    return channel_ratios

# %%
get_checkbox_ratios(da_2018,"Q11")
# Out:
# Analyze and understand data to influence product or business decisions                                              0.414894
# Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data    0.196647
# Build prototypes to explore applying machine learning to new areas                                                  0.137331
# Build and/or run a machine learning service that operationally improves my product or workflows                     0.116054
# Do research that advances the state of the art of machine learning                                                  0.081560
# None of these activities are an important part of my role at work                                                   0.031270
# Other                                                                                                               0.022244
# dtype: float64
